# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import nltk
import re

from utils.utils import *
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\1\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv('QueryResults(1).csv')
df.head()
# Out:
#     post_id  parent_id                                              Title  \
# 0  68831096        NaN  Why can't std::stringstream be default constru...
# 1  68831096        NaN  Why can't std::stringstream be default constru...
# 2  68831096        NaN  Why can't std::stringstream be default constru...
# 3  68831099        NaN                   Transform an Array in JavaScript
# 4  68831099        NaN                   Transform an Array in JavaScript
#
#                                            post_text     com_id  \
# 0  <p>The following compiles fine (on g++ 8.3.0-6...  121644544
# 1  <p>The following compiles fine (on g++ 8.3.0-6...  121644785
# 2  <p>The following compiles fine (on g++ 8.3.0-6...  121644610
# 3  <p>I  have a simple problem that I can't solve...  121644586
# 4  <p>I  have a simple problem that I can't solve...  121644602
#
#                                             com_text  com_user_id  reputation  \
# 0  works fine with newer version https://godbolt....      4117728       81863
# 1  Seems to be the same question: [Why GCC doesn'...      7976805       14493
# 2     Looks like compiler bug, it works with GCC 9.1      7976805       14493
# 3  there should be examples of how to do this, it...       301774        6388
# 4  https://stackoverflow.com/questions/37075180/c...       301774        6388
#
#                     dt
# 0  2021-08-18 10:59:42
# 1  2021-08-18 10:59:42
# 2  2021-08-18 10:59:42
# 3  2021-08-18 10:59:46
# 4  2021-08-18 10:59:46

# %%
post_text = list(set(df['post_text'].fillna('')))
com_text = list(set(df['com_text'].fillna('')))
title_text = list(set(df['Title'].fillna('')))
text = post_text + com_text + title_text

# %%
 # Разделим текст на предложения
lst = split_text(text)

# %%
# %%time
 # Составим словарь частоты повторения фраз длины 2
stop_words = stopwords.words('english')
cr = CountVectorizer(max_features = 300, ngram_range=(2,2), preprocessor = my_cool_preprocessor, stop_words = stop_words)
cr_vector=cr.fit_transform(lst).toarray()
# Out:
# Wall time: 36.2 s

# %%
# %%time
names = cr.get_feature_names()
count = [np.sum(cr_vector[:,i]) for i in range(cr_vector.shape[1])]
dc = sort_dict(dict(zip(names, count)))
# Out:
# Wall time: 2.82 s

# %%
dc
# Out:
# {'href http': 9017,
#  'rel nofollow': 7880,
#  'nofollow noreferrer': 7879,
#  'http stackoverflow': 3055,
#  'src http': 2855,
#  'img src': 2734,
#  'div class': 2489,
#  'png rel': 2454,
#  'div div': 2394,
#  'noreferrer img': 2217,
#  'png alt': 2146,
#  'http www': 2125,
#  'com question': 2061,
#  'image description': 1763,
#  'enter image': 1759,
#  'alt enter': 1637,
#  'look like': 1561,
#  'noreferrer http': 1534,
#  'http doc': 1509,
#  'http github': 1501,
#  'text text': 1189,
#  'something like': 1133,
#  'java org': 1073,
#  'would like': 1004,
#  'td td': 806,
#  'public void': 805,
#  'error message': 798,
#  'type text': 757,
#  'public class': 750,
#  'com en': 736,
#  'thank much': 731,
#  'http developer': 718,
#  'answer question': 686,
#  'get error': 657,
#  'input type': 634,
#  'work fine': 627,
#  'get set': 622,
#  'html rel': 598,
#  'background color': 574,
#  'make sure': 570,
#  'site package': 557,
#  'class form': 530,
#  'getting error': 517,
#  'doe work': 512,
#  'make sense': 511,
#  'public static': 500,
#  'want use': 491,
#  'option value': 483,
#  'file user': 477,
#  'org doc': 472,
#  'na na': 469,
#  'lib python': 459,
#  'option option': 457,
#  'int main': 443,
#  'public string': 442,
#  'override public': 429,
#  'width px': 425,
#  'need use': 424,
#  'error error': 418,
#  'http localhost': 416,
#  'please help': 414,
#  'id id': 413,
#  'dependency dependency': 404,
#  'org en': 401,
#  'export default': 395,
#  'script src': 382,
#  'following error': 381,
#  'height px': 377,
#  'font size': 375,
#  'visual studio': 373,
#  'every time': 370,
#  'let know': 369,
#  'create new': 361,
#  'could use': 360,
#  'doc web': 354,
#  'en doc': 352,
#  'return true': 352,
#  'solve problem': 350,
#  'sql server': 346,
#  'http en': 345,
#  'set public': 344,
#  'com doc': 343,
#  'div classname': 343,
#  'seems like': 343,
#  'doe answer': 342,
#  'name name': 340,
#  'px px': 339,
#  '__init__ self': 337,
#  'csv file': 337,
#  'div id': 336,
#  'url http': 336,
#  'react native': 335,
#  'artifactid version': 334,
#  'java android': 331,
#  'return value': 325,
#  'com help': 323,
#  'following code': 322,
#  'text align': 322,
#  'content type': 320,
#  'data data': 320,
#  'return false': 320,
#  'code work': 319,
#  'appdata local': 313,
#  'thanks advance': 313,
#  'jpg rel': 311,
#  'thanks lot': 307,
#  'td tr': 305,
#  'function return': 302,
#  'form control': 301,
#  'spring boot': 300,
#  'jpg alt': 297,
#  'value value': 296,
#  'add new': 295,
#  'column name': 295,
#  'command line': 295,
#  'align center': 293,
#  'dp android': 292,
#  'see http': 291,
#  'usr lib': 291,
#  'int int': 288,
#  'java com': 285,
#  'json file': 285,
#  'user user': 285,
#  'return new': 284,
#  'rat cat': 282,
#  'cat rat': 281,
#  'edit question': 277,
#  'pip install': 277,
#  'static void': 276,
#  'android layout_height': 275,
#  'npm err': 275,
#  'android layout_width': 274,
#  'use href': 270,
#  'df df': 269,
#  'tot jaar': 268,
#  'use case': 267,
#  'else return': 265,
#  'also tried': 264,
#  'program file': 264,
#  'private string': 263,
#  'std cout': 262,
#  'import java': 261,
#  'usr local': 260,
#  'could please': 259,
#  'create table': 259,
#  'application json': 258,
#  'def __init__': 258,
#  'span class': 258,
#  'nan nan': 257,
#  'class col': 256,
#  'even though': 256,
#  'primary key': 256,
#  'source code': 255,
#  'reproducible example': 254,
#  'import org': 253,
#  'thanks help': 253,
#  'stack overflow': 251,
#  'expected output': 250,
#  'using system': 250,
#  'button div': 248,
#  'wa able': 248,
#  'width height': 248,
#  'tried using': 247,
#  'item item': 246,
#  'java java': 244,
#  'data type': 243,
#  'void main': 242,
#  'doe exist': 241,
#  'give error': 240,
#  'net core': 239,
#  'break case': 238,
#  'hello world': 237,
#  'trying use': 236,
#  'version dependency': 236,
#  'best way': 235,
#  'return div': 235,
#  'color color': 234,
#  'python python': 234,
#  'type string': 233,
#  'px solid': 230,
#  'file name': 229,
#  'get data': 229,
#  'df pd': 228,
#  'method post': 228,
#  'docker compose': 227,
#  'public function': 227,
#  'would need': 227,
#  'like href': 226,
#  'org wiki': 225,
#  'sample data': 224,
#  'line code': 223,
#  'std string': 223,
#  'working fine': 223,
#  'call function': 222,
#  'see href': 222,
#  'uint _t': 221,
#  'updated answer': 221,
#  'let say': 217,
#  'new date': 217,
#  'run code': 217,
#  'app web': 216,
#  'async function': 215,
#  'btn btn': 215,
#  'data frame': 215,
#  'padding px': 215,
#  'python lib': 215,
#  'key value': 214,
#  'private void': 214,
#  'got error': 213,
#  'text file': 212,
#  'get following': 211,
#  'button button': 210,
#  'chr chr': 210,
#  'class btn': 210,
#  'android id': 209,
#  'user input': 209,
#  'charset utf': 207,
#  'end end': 207,
#  'lib site': 206,
#  'need add': 206,
#  'please check': 206,
#  'rel stylesheet': 206,
#  'using href': 206,
#  'border px': 205,
#  'work well': 205,
#  'get value': 204,
#  'size px': 204,
#  'display flex': 203,
#  'string name': 203,
#  'http api': 202,
#  'import react': 202,
#  'recent call': 202,
#  'dependency groupidorg': 201,
#  'something else': 201,
#  'call last': 200,
#  'justify content': 200,
#  'str varchar': 200,
#  'usr bin': 200,
#  'button class': 199,
#  'script script': 199,
#  'varchar str': 199,
#  'traceback recent': 198,
#  'trying create': 198,
#  'trying get': 198,
#  'want create': 197,
#  'first time': 196,
#  'sound like': 196,
#  'take look': 196,
#  'make work': 195,
#  'win amd': 192,
#  'cannot find': 191,
#  'ct ct': 191,
#  'main string': 191,
#  'exact true': 190,
#  'want add': 190,
#  'android studio': 189,
#  'want get': 189,
#  'link href': 188,
#  'thanks answer': 188,
#  'build lib': 187,
#  'end sub': 187,
#  'label input': 187,
#  'please provide': 187,
#  'public int': 187,
#  'return result': 187,
#  'variable name': 187,
#  'wrap_content android': 187,
#  'itemprops exact': 185,
#  'list list': 185,
#  'want make': 185,
#  'blob master': 184,
#  'font weight': 184,
#  'line line': 184,
#  'string args': 183,
#  'top px': 183,
#  'help would': 182,
#  'code snippet': 181,
#  'file directory': 181,
#  'import package': 181,
#  'return self': 181,
#  'span div': 181,
#  'api call': 179,
#  'better way': 179,
#  'position absolute': 179,
#  'react import': 179,
#  'return null': 179,
#  'type application': 179,
#  'fa fa': 178,
#  'http schema': 178,
#  'import panda': 178,
#  'left join': 178,
#  'self self': 178,
#  'try use': 178,
#  'body html': 177,
#  'code import': 177,
#  'type button': 177,
#  'web api': 177,
#  'work perfectly': 177,
#  'would work': 177,
#  'environment variable': 176}

# %% [markdown]
# Исключим фразы с некоторыми словами, которые используются только для написания кода.
# Есть и другие "вредные" фразы, слова, но определить их всех очень тяжело. Поэтому я нашёл первую "осмысленную" фразу и убрал все фразы с большей частотой. Так я оставил фразы только частоты <= частота 'image description'

# %%
words = ['http', 'int', 'float', 'com', 'nan', 'html', 'href']
chk_pat = '(?:{})'.format('|'.join(words))
dc1 = {k:v for k, v in dc.items() if v <= dc['image description'] and not bool(re.search(chk_pat, k, flags=re.I))}

# %%
sns.set(font_scale=1.3)
plt.figure(figsize=(14, 7))
plt.subplots_adjust(hspace=0.5)

plt.title('Number of repetitions of words in sentences')
plt.barh(list(dc1.keys())[:7][::-1], list(dc1.values())[:7][::-1], color=['b', 'g', 'r', 'm', 'y', 'k'])
plt.xlabel('number')

plt.show()

# %%
plot_history(dc1, a = 200, b = 15, xtitle = False)

# %%
 # сохраним в файл csv
history_path_to_save='./phrases2.csv'
pd.DataFrame(list(dc1.items())).to_csv(history_path_to_save, index = False)

# %% [markdown]
# # Фразы из 3-х слов

# %%
# %%time
stop_words = stopwords.words('english')
cr1 = CountVectorizer(max_features = 300, ngram_range=(3,3), preprocessor = my_cool_preprocessor, stop_words = stop_words)
cr_vector1=cr1.fit_transform(lst).toarray()
# Out:
# Wall time: 36.6 s

# %%
# %%time
names1 = cr1.get_feature_names()
count1 = [np.sum(cr_vector1[:,i]) for i in range(cr_vector1.shape[1])]
dc1 = sort_dict(dict(zip(names1, count1)))
# Out:
# Wall time: 1.87 s

# %%
dc1
# Out:
# {'rel nofollow noreferrer': 7879,
#  'img src http': 2494,
#  'png rel nofollow': 2417,
#  'noreferrer img src': 2216,
#  'nofollow noreferrer img': 2181,
#  'enter image description': 1758,
#  'alt enter image': 1634,
#  'nofollow noreferrer http': 1510,
#  'png alt enter': 1425,
#  'text text text': 1033,
#  'div div class': 865,
#  'href http www': 812,
#  'href http stackoverflow': 781,
#  'div div div': 775,
#  'href http doc': 756,
#  'href http github': 661,
#  'html rel nofollow': 580,
#  'href http developer': 392,
#  'na na na': 364,
#  'org en doc': 335,
#  'doe answer question': 330,
#  'option option value': 330,
#  'get set public': 324,
#  'en doc web': 321,
#  'td td td': 312,
#  'jpg rel nofollow': 310,
#  'override public void': 285,
#  'use href http': 266,
#  'rat cat rat': 265,
#  'cat rat cat': 263,
#  'class form control': 258,
#  'def __init__ self': 257,
#  'input type text': 251,
#  'script src http': 251,
#  'text align center': 251,
#  'div class col': 226,
#  'noreferrer http github': 223,
#  'see href http': 220,
#  'like href http': 219,
#  'android id id': 209,
#  'noreferrer http www': 209,
#  'lib site package': 206,
#  'version dependency dependency': 204,
#  'using href http': 203,
#  'str varchar str': 199,
#  'varchar str varchar': 199,
#  'recent call last': 198,
#  'traceback recent call': 198,
#  'font size px': 194,
#  'public static void': 194,
#  'dependency dependency groupidorg': 192,
#  'border px solid': 188,
#  'ct ct ct': 186,
#  'itemprops exact true': 185,
#  'class btn btn': 179,
#  'nan nan nan': 177,
#  'static void main': 175,
#  'import panda pd': 174,
#  'main string args': 168,
#  'void main string': 168,
#  'jpg alt enter': 166,
#  'import numpy np': 164,
#  'noreferrer http doc': 163,
#  'doc web javascript': 161,
#  'content type application': 157,
#  'invalid length startup': 157,
#  'length startup packet': 157,
#  'log invalid length': 156,
#  'utc log invalid': 156,
#  'com ajax libs': 152,
#  'web javascript reference': 152,
#  'get following error': 151,
#  'px height px': 151,
#  'android layout_width match_parent': 150,
#  'call last file': 150,
#  'description href http': 150,
#  'href http en': 150,
#  'bigint intg bigint': 149,
#  'class fa fa': 149,
#  'intg bigint intg': 149,
#  'layout_width match_parent android': 149,
#  'td tr tr': 149,
#  'com en dotnet': 147,
#  'minimal reproducible example': 147,
#  'div class form': 145,
#  'match_parent android layout_height': 145,
#  'image description href': 143,
#  'android layout_height wrap_content': 140,
#  'width px height': 140,
#  'class form group': 139,
#  'appdata local program': 138,
#  'px px px': 137,
#  'local program python': 136,
#  'program python python': 136,
#  'type application json': 136,
#  'doctype html html': 135,
#  'set public string': 134,
#  'answer http stackoverflow': 133,
#  'library ruby gem': 133,
#  'label input type': 131,
#  'int main int': 129,
#  'please let know': 125,
#  'script script src': 124,
#  'question http stackoverflow': 123,
#  'dart import package': 121,
#  'yyyy mm dd': 120,
#  'link rel stylesheet': 119,
#  'type text class': 119,
#  'div class container': 117,
#  'layout_height wrap_content android': 117,
#  'using namespace std': 115,
#  'align item center': 114,
#  'cannot read property': 114,
#  'flex justify content': 112,
#  'nofollow noreferrer enter': 111,
#  'copying src lxml': 110,
#  'doe anyone know': 110,
#  'init static let': 110,
#  'lib go src': 108,
#  'site package django': 108,
#  'usr lib go': 108,
#  'doc web api': 106,
#  'meta charset utf': 106,
#  'noreferrer enter image': 106,
#  'button div div': 105,
#  'issue rel nofollow': 105,
#  'please edit question': 105,
#  'appdata local temp': 102,
#  'div class row': 102,
#  'header content type': 102,
#  'python python lib': 101,
#  'border radius px': 100,
#  'link href http': 100,
#  'rel stylesheet href': 100,
#  'var body view': 100,
#  'td td class': 99,
#  'example href http': 97,
#  'example http stackoverflow': 96,
#  'include iostream include': 96,
#  'javascript reference global_objects': 96,
#  'artifactid dependency dependency': 95,
#  'button type button': 95,
#  'justify content center': 95,
#  'en dotnet api': 94,
#  'go src net': 94,
#  'object ha attribute': 94,
#  'option value option': 94,
#  'py build lib': 94,
#  'widget build buildcontext': 94,
#  'build buildcontext context': 93,
#  'debug wire http': 93,
#  'div class modal': 92,
#  'head meta charset': 92,
#  'import react react': 92,
#  'src http cdnjs': 92,
#  'style text align': 92,
#  'look something like': 91,
#  'see http stackoverflow': 91,
#  'type text javascript': 91,
#  'div export default': 90,
#  'usr local lib': 90,
#  'buildcontext context return': 89,
#  'python lib site': 89,
#  'width device width': 89,
#  'chr chr chr': 88,
#  'com en azure': 88,
#  'file frozen importlib': 88,
#  'class col md': 87,
#  'name viewport content': 87,
#  'return div classname': 87,
#  'span div div': 87,
#  'content width device': 86,
#  'max width px': 86,
#  'override widget build': 86,
#  'meta name viewport': 85,
#  'nofollow noreferrer documentation': 85,
#  'viewport content width': 85,
#  'button class btn': 84,
#  'datetime insert testdata': 84,
#  'div class card': 84,
#  'dolor sit amet': 84,
#  'insert testdata select': 84,
#  'margin top px': 84,
#  'access control allow': 83,
#  'display inline block': 83,
#  'help minimal reproducible': 83,
#  'value option option': 83,
#  'com help minimal': 82,
#  'href http cloud': 80,
#  'html lang en': 80,
#  'private static final': 80,
#  'typeerror cannot read': 80,
#  'dotnet api system': 78,
#  'look like href': 78,
#  'type text name': 77,
#  'react react import': 76,
#  'ajax libs jquery': 75,
#  'html html lang': 75,
#  'numpy np import': 75,
#  'script type text': 75,
#  'com rel nofollow': 74,
#  'gif rel nofollow': 74,
#  'help would appreciated': 74,
#  'http sender dispatcher': 74,
#  'noreferrer http developer': 74,
#  'wire http sender': 74,
#  'container div class': 73,
#  'px width px': 73,
#  'welcome stack overflow': 73,
#  'android layout_height dp': 72,
#  'gyp verb failed': 72,
#  'let keypress key': 72,
#  'local lib python': 72,
#  'static let keypress': 72,
#  'textinput attrs placeholder': 72,
#  'would greatly appreciated': 72,
#  'android layout_width wrap_content': 71,
#  'chat http chat': 71,
#  'com room discussion': 70,
#  'div class flex': 70,
#  'input type checkbox': 70,
#  'io en latest': 70,
#  'layout_width wrap_content android': 70,
#  'org doc handbook': 70,
#  'padding px px': 70,
#  'wrap_content android layout_height': 70,
#  'xsl value select': 70,
#  'code href http': 69,
#  'jar opt kafka_': 69,
#  'div div classname': 68,
#  'normal block ac': 68,
#  'panda pd import': 68,
#  'found href http': 67,
#  'lang en head': 67,
#  'override protected void': 67,
#  'python lib python': 67,
#  'read property undefined': 67,
#  'usr local bin': 67,
#  'visual studio code': 67,
#  'charset utf meta': 66,
#  'code look like': 66,
#  'continue discussion chat': 66,
#  'dependency dependency groupidcom': 66,
#  'discussion chat http': 66,
#  'form control mt': 66,
#  'heroku python lib': 66,
#  'let continue discussion': 66,
#  'reproducible example http': 66,
#  'text class form': 66,
#  'would like know': 66,
#  'form group label': 65,
#  'px background color': 65,
#  'read href http': 65,
#  'row div class': 65,
#  'cs rel stylesheet': 64,
#  'div div id': 64,
#  'error href http': 64,
#  'li lia href': 64,
#  'output href http': 64,
#  'apt get install': 63,
#  'href http codesandbox': 63,
#  'type button class': 63,
#  'property undefined reading': 62,
#  'style border px': 62,
#  'gem cocoapods core': 61,
#  'lib cocoapods core': 61,
#  'android layout_height match_parent': 60,
#  'android layout_margintop dp': 60,
#  'charfield required false': 60,
#  'class row div': 60,
#  'com question use': 60,
#  'height px width': 60,
#  'layout_height dp android': 60,
#  'en head meta': 59,
#  'self return self': 59,
#  'app src main': 58,
#  'debug nio exec': 58,
#  'export default function': 58,
#  'html html head': 58,
#  'position absolute top': 58,
#  'shadow px px': 58,
#  'text decoration none': 58,
#  'thank much help': 58,
#  'thumbnail preview indicator': 58,
#  'android textsize sp': 57,
#  'aria hidden true': 57,
#  'dbl dbl dbl': 57,
#  'getting following error': 57,
#  'href http jsfiddle': 57,
#  'library dplyr library': 57,
#  'result href http': 57,
#  'script body html': 57,
#  'would look like': 57,
#  'control allow origin': 56,
#  'fo table cell': 56,
#  'meta http equiv': 56,
#  'modulenotfounderror module named': 56,
#  'query alter table': 56,
#  'react router dom': 56,
#  'scope dependency dependency': 56}

# %% [markdown]
# Исключим фразы с некоторыми словами, которые используются только для написания кода.
# Есть и другие "вредные" фразы, слова, но определить их всех очень тяжело. Поэтому я нашёл первую "осмысленную" фразу и убрал все фразы с большей частотой. Так я оставил фразы только частоты <= частота 'enter image description'

# %%
 # Исключим фразы с некоторыми словами, 
 # которые используются при написания кода
words = ['http', 'int', 'float', 'com', 'nan', 'html', 'href']
chk_pat = '(?:{})'.format('|'.join(words))
dc2 = {k:v for k, v in dc1.items() if v <= dc1['enter image description'] and not bool(re.search(chk_pat, k, flags=re.I))}

# %%
sns.set(font_scale=1.3)
plt.figure(figsize=(14, 7))
plt.subplots_adjust(hspace=0.5)

plt.title('Number of repetitions of words in sentences')
plt.barh(list(dc2.keys())[:7][::-1], list(dc2.values())[:7][::-1], color=['b', 'g', 'r', 'm', 'y', 'k'])
plt.xlabel('number')

plt.show()

# %%
plot_history(dc2, a = 200, b = 21, xtitle = False)

# %%
 # сохраним в файл csv
history_path_to_save='./phrases3.csv'
pd.DataFrame(list(dc2.items())).to_csv(history_path_to_save, index = False)

# %% [markdown]
# # Выводы

# %% [markdown]
# Заметим, что частотный анализ фраз, состоящих из 3-х и 2-х слов оказался плохим. Пришлось ставить ограничение на частоту фразы и отдельно исключать фразы с "вредными" словами: "http", "href" и так далее. В общем случае это довольно трудоемкий процесс
#
# Можно сделать вывод, что искать фразы лучше другим способом
